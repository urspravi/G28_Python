# %% [markdown]
# Problem Statement: Predicting App Ratings
# Project Description: Build a regression model to predict the ratings of mobile applications based on user reviews, app features, developer details, and historical ratings.
# Domain: Mobile Applications

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("/content/drive/MyDrive/ML_Datasets/googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.drop(df[df['Reviews']=='3.0M'].index,inplace=True)

# %%
df["Reviews"] = df["Reviews"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %%
df['Size'] = df['Size'].str.replace('M','000')
df['Size'] = df['Size'].str.replace('k','')
df['Size'] = df['Size'].replace('Varies with device',np.nan)

# %%
pd.DataFrame(df['Size'])
# Out:
#          Size
# 0       19000
# 1       14000
# 2      8.7000
# 3       25000
# 4      2.8000
# ...       ...
# 10836   53000
# 10837  3.6000
# 10838  9.5000
# 10839     NaN
# 10840   19000
#
# [10840 rows x 1 columns]

# %%
df['Size']=df['Size'].astype(float)

# %%
for i in df['Size']:
    if i < 10:
        df['Size']=df['Size'].replace(i,i*1000)
df['Size']=df['Size']/1000
df['Size']
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 10840, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.2+ MB

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews  Size     Installs  Type Price Content Rating  \
# 10836     4.5       38  53.0       5,000+  Free     0       Everyone
# 10837     5.0        4   3.6         100+  Free     0       Everyone
# 10838     NaN        3   9.5       1,000+  Free     0       Everyone
# 10839     4.5      114   NaN       1,000+  Free     0     Mature 17+
# 10840     4.5   398307  19.0  10,000,000+  Free     0       Everyone
#
#                   Genres      Last Updated         Current Ver  \
# 10836          Education     July 25, 2017                1.48
# 10837          Education      July 6, 2018                 1.0
# 10838            Medical  January 20, 2017                 1.0
# 10839  Books & Reference  January 19, 2015  Varies with device
# 10840          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
df['Installs']=df['Installs'].str.replace("+",'')
df['Installs']=df['Installs'].str.replace(",",'')

df['Price']=df['Price'].str.replace("$",'')

df.head()
# Out:
# <ipython-input-105-1be6b845be37>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Installs']=df['Installs'].str.replace("+",'')
# <ipython-input-105-1be6b845be37>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price']=df['Price'].str.replace("$",'')
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159  19.0     10000  Free     0       Everyone
# 1      967  14.0    500000  Free     0       Everyone
# 2    87510   8.7   5000000  Free     0       Everyone
# 3   215644  25.0  50000000  Free     0           Teen
# 4      967   2.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df['Installs'] = df['Installs'].astype(int)
df['Price'] = df['Price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])
df['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10840, dtype: datetime64[ns]

# %%
df['Month']=df['Last Updated'].dt.month
df['Year']=df['Last Updated'].dt.year

# %%
df.drop('Last Updated', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres         Current Ver   Android Ver  Month  Year
# 0               Art & Design               1.0.0  4.0.3 and up      1  2018
# 1  Art & Design;Pretend Play               2.0.0  4.0.3 and up      1  2018
# 2               Art & Design               1.2.4  4.0.3 and up      8  2018
# 3               Art & Design  Varies with device    4.2 and up      6  2018
# 4    Art & Design;Creativity                 1.1    4.4 and up      6  2018

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Current Ver          8
# Android Ver          2
# Month                0
# Year                 0
# dtype: int64

# %%
df['Rating']=df['Rating'].fillna(df['Rating'].median())

# %%
df['Size']=df['Size'].fillna(df['Size'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Current Ver     10832 non-null  object
#  11  Android Ver     10838 non-null  object
#  12  Month           10840 non-null  int64
#  13  Year            10840 non-null  int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       8
# Android Ver       2
# Month             0
# Year              0
# dtype: int64

# %%
df['Type']=df['Type'].fillna(df['Type'].mode().values[0])

# %%
df.duplicated().sum()
# Out:
# 484

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (10356, 14)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       8
# Android Ver       2
# Month             0
# Year              0
# dtype: int64

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df['Android Ver'] = df['Android Ver'].apply(lambda x: np.nan if x=='Varies with device' else x)

# %%
df['Android Ver'] = df['Android Ver'].str[:3]

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0', '4.2', '4.4', '2.3', '3.0', '4.1', nan, '2.2', '5.0', '6.0',
#        '1.6', '1.5', '2.1', '7.0', '5.1', '4.3', '2.0', '3.2', '7.1',
#        '8.0', '3.1', '1.0'], dtype=object)

# %%
df['Android Ver'].astype(float)
# Out:
# 0        4.0
# 1        4.0
# 2        4.0
# 3        4.2
# 4        4.4
#         ...
# 10836    4.1
# 10837    4.1
# 10838    2.2
# 10839    NaN
# 10840    NaN
# Name: Android Ver, Length: 10356, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10356 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10356 non-null  object
#  1   Category        10356 non-null  object
#  2   Rating          10356 non-null  float64
#  3   Reviews         10356 non-null  int64
#  4   Size            10356 non-null  float64
#  5   Installs        10356 non-null  int64
#  6   Type            10356 non-null  object
#  7   Price           10356 non-null  float64
#  8   Content Rating  10356 non-null  object
#  9   Genres          10356 non-null  object
#  10  Current Ver     10348 non-null  object
#  11  Android Ver     9133 non-null   object
#  12  Month           10356 non-null  int64
#  13  Year            10356 non-null  int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating               0
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Current Ver          8
# Android Ver       1223
# Month                0
# Year                 0
# dtype: int64

# %%
df['Android Ver']=df['Android Ver'].fillna(df['Android Ver'].median())

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       8
# Android Ver       0
# Month             0
# Year              0
# dtype: int64

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres         Current Ver Android Ver  Month  Year
# 0               Art & Design               1.0.0         4.0      1  2018
# 1  Art & Design;Pretend Play               2.0.0         4.0      1  2018
# 2               Art & Design               1.2.4         4.0      8  2018
# 3               Art & Design  Varies with device         4.2      6  2018
# 4    Art & Design;Creativity                 1.1         4.4      6  2018

# %%
df.describe()
# Out:
#              Rating       Reviews          Size      Installs         Price  \
# count  10356.000000  1.035600e+04  10356.000000  1.035600e+04  10356.000000
# mean       4.203737  4.059308e+05     20.059381  1.415816e+07      1.030900
# std        0.485618  2.696907e+06     21.026420  8.024342e+07     16.279408
# min        1.000000  0.000000e+00      0.010000  0.000000e+00      0.000000
# 25%        4.100000  3.200000e+01      5.700000  1.000000e+03      0.000000
# 50%        4.300000  1.678500e+03     13.000000  1.000000e+05      0.000000
# 75%        4.500000  4.638075e+04     26.000000  1.000000e+06      0.000000
# max        5.000000  7.815831e+07    100.000000  1.000000e+09    400.000000
#
#               Month          Year
# count  10356.000000  10356.000000
# mean       6.396871   2017.382870
# std        2.606437      1.112803
# min        1.000000   2010.000000
# 25%        5.000000   2017.000000
# 50%        7.000000   2018.000000
# 75%        8.000000   2018.000000
# max       12.000000   2018.000000

# %%
corr_data = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_data,annot=True)
plt.show()
# Out:
# <ipython-input-135-28d3cd3a86a2>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_data = df.corr()

# %%
import matplotlib.pyplot as plt

df.hist(bins=50,figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=(14, 10))

sns.countplot(data=df, y='Category')

plt.title('Number of Apps per Category')
plt.show()

# %%
sns.histplot(data=df, x='Rating', kde=True)

plt.title('Distribution of Rating')
plt.show()

# %%
sns.scatterplot(x=df['Rating'], y=df['Reviews'] ,data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %%
sns.lineplot(x=df['Rating'], y=df['Reviews'] ,data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %%
sns.lineplot(x=df['Rating'], y=df['Size'] ,data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Size'>

# %%
sns.lineplot(x=df['Rating'], y=df['Installs'] ,data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Installs'>

# %%
sns.lineplot(x=df['Rating'], y=df['Price'] ,data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Price'>

# %%
sns.scatterplot(data=df, x='Size', y='Rating', hue='Type', s=40)

plt.title('Rating vs. Size as per Type')
plt.show()

# %%
sns.countplot(x=df.Type,data=df)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.histplot(data=df, x='Reviews', bins=60, kde=True)

plt.title('Distribution of Reviews')
plt.show()

# %%
sns.countplot(y=df['Content Rating'],data=df)
# Out:
# <Axes: xlabel='count', ylabel='Content Rating'>

# %%
sns.countplot(data=df, y='Android Ver')

plt.title('Count of Apps with supported Android Version')
plt.show()

# %%
sns.histplot(data=df, x='Year', bins=60, kde=True)
plt.show()

# %%
to_be_drop_col = ['App','Genres','Current Ver']

df.drop(to_be_drop_col, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10356 entries, 0 to 10840
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10356 non-null  object
#  1   Rating          10356 non-null  float64
#  2   Reviews         10356 non-null  int64
#  3   Size            10356 non-null  float64
#  4   Installs        10356 non-null  int64
#  5   Type            10356 non-null  object
#  6   Price           10356 non-null  float64
#  7   Content Rating  10356 non-null  object
#  8   Android Ver     10356 non-null  object
#  9   Month           10356 non-null  int64
#  10  Year            10356 non-null  int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 970.9+ KB

# %%
df.head()
# Out:
#          Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510   8.7   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967   2.8    100000  Free    0.0
#
#   Content Rating Android Ver  Month  Year
# 0       Everyone         4.0      1  2018
# 1       Everyone         4.0      1  2018
# 2       Everyone         4.0      8  2018
# 3           Teen         4.2      6  2018
# 4       Everyone         4.4      6  2018

# %%
categorical_columns=['Category','Type','Content Rating']

# %%
le = LabelEncoder()
for col in categorical_columns:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Category  Rating  Reviews  Size  Installs  Type  Price  Content Rating  \
# 0         0     4.1      159  19.0     10000     0    0.0               1
# 1         0     3.9      967  14.0    500000     0    0.0               1
# 2         0     4.7    87510   8.7   5000000     0    0.0               1
# 3         0     4.5   215644  25.0  50000000     0    0.0               4
# 4         0     4.3      967   2.8    100000     0    0.0               1
#
#   Android Ver  Month  Year
# 0         4.0      1  2018
# 1         4.0      1  2018
# 2         4.0      8  2018
# 3         4.2      6  2018
# 4         4.4      6  2018

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10356 entries, 0 to 10840
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10356 non-null  int64
#  1   Rating          10356 non-null  float64
#  2   Reviews         10356 non-null  int64
#  3   Size            10356 non-null  float64
#  4   Installs        10356 non-null  int64
#  5   Type            10356 non-null  int64
#  6   Price           10356 non-null  float64
#  7   Content Rating  10356 non-null  int64
#  8   Android Ver     10356 non-null  object
#  9   Month           10356 non-null  int64
#  10  Year            10356 non-null  int64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 970.9+ KB

# %%
numeric_columns=df.drop(['Category','Type','Content Rating'],axis=1)
numeric_columns.columns
# Out:
# Index(['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Android Ver',
#        'Month', 'Year'],
#       dtype='object')

# %%
scaler = StandardScaler()

df[numeric_columns.columns] = scaler.fit_transform(df[numeric_columns.columns])

# %%
df.head()
# Out:
#    Category    Rating   Reviews      Size  Installs  Type     Price  \
# 0         0 -0.213629 -0.150466 -0.050386 -0.176324     0 -0.063328
# 1         0 -0.625495 -0.150166 -0.288193 -0.170217     0 -0.063328
# 2         0  1.021970 -0.118075 -0.540269 -0.114135     0 -0.063328
# 3         0  0.610104 -0.070561  0.234983  0.446685     0 -0.063328
# 4         0  0.198238 -0.150166 -0.820882 -0.175202     0 -0.063328
#
#    Content Rating  Android Ver     Month      Year
# 0               1     0.147739 -2.070693  0.554599
# 1               1     0.147739 -2.070693  0.554599
# 2               1     0.147739  0.615095  0.554599
# 3               4     0.399176 -0.152273  0.554599
# 4               1     0.650612 -0.152273  0.554599

# %%
df.describe()
# Out:
#            Category        Rating       Reviews          Size      Installs  \
# count  10356.000000  1.035600e+04  1.035600e+04  1.035600e+04  1.035600e+04
# mean      16.744593  3.073804e-16 -1.646681e-17 -4.253925e-17 -1.097787e-17
# std        8.358433  1.000048e+00  1.000048e+00  1.000048e+00  1.000048e+00
# min        0.000000 -6.597557e+00 -1.505245e-01 -9.535788e-01 -1.764487e-01
# 25%       11.000000 -2.136288e-01 -1.505126e-01 -6.829538e-01 -1.764362e-01
# 50%       14.000000  1.982375e-01 -1.499021e-01 -3.357548e-01 -1.752024e-01
# 75%       25.000000  6.101038e-01 -1.333259e-01  2.825448e-01 -1.639860e-01
# max       32.000000  1.639770e+00  2.883160e+01  3.802096e+00  1.228623e+01
#
#                Type         Price  Content Rating   Android Ver         Month  \
# count  10356.000000  1.035600e+04    10356.000000  1.035600e+04  1.035600e+04
# mean       0.073870 -3.087526e-18        1.455195 -3.183583e-16 -3.430585e-17
# std        0.261572  1.000048e+00        1.000638  1.000048e+00  1.000048e+00
# min        0.000000 -6.332845e-02        0.000000 -3.623803e+00 -2.070693e+00
# 25%        0.000000 -6.332845e-02        1.000000  1.477394e-01 -5.359572e-01
# 50%        0.000000 -6.332845e-02        1.000000  2.734575e-01  2.314108e-01
# 75%        0.000000 -6.332845e-02        1.000000  2.734575e-01  6.150948e-01
# max        1.000000  2.450878e+01        5.000000  5.176462e+00  2.149831e+00
#
#                Year
# count  1.035600e+04
# mean  -5.076168e-14
# std    1.000048e+00
# min   -6.634799e+00
# 25%   -3.440754e-01
# 50%    5.545993e-01
# 75%    5.545993e-01
# max    5.545993e-01

# %%
x=df.drop(['Rating'],axis=1)
y=df['Rating']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8284, 10)
# (2072, 10)
# (8284,)
# (2072,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred1 = lr.predict(x_test)

# %%
y_pred1
# Out:
# array([ 0.07282825,  0.05057783,  0.07872248, ..., -0.04463511,
#        -0.06682739,  0.05607031])

# %%
print("MSE : ",mean_squared_error(y_pred1,y_test))
print("MAE : ",mean_absolute_error(y_pred1,y_test))
print("R Score :",r2_score(y_pred1,y_test))
# Out:
# MSE :  0.9900312139340575
# MAE :  0.6737786287577536
# R Score : -41.34498263293167

# %%
svm = SVR(kernel = "linear")
svm.fit(x_train,y_train)
y_pred2 = svm.predict(x_test)

# %%
y_pred2
# Out:
# array([0.15683482, 0.26009546, 0.20121179, ..., 0.1868092 , 0.17554099,
#        0.196139  ])

# %%
print("MSE : ",mean_squared_error(y_pred2,y_test))
print("MAE : ",mean_absolute_error(y_pred2,y_test))
print("R Score :",r2_score(y_pred2,y_test))
# Out:
# MSE :  1.0471973465819835
# MAE :  0.6475838889134489
# R Score : -55.06855041599551

# %%
PF = PolynomialFeatures(degree=3)
x_train_poly = pd.DataFrame(PF.fit_transform(x_train))
x_test_poly = pd.DataFrame(PF.fit_transform(x_test))

print(x_train_poly)
print(x_test_poly)
# Out:
#       0     1         2         3         4    5         6    7         8    \
# 0     1.0  14.0 -0.146617  1.424021 -0.163986  0.0 -0.063328  3.0 -1.989468
# 1     1.0  13.0 -0.094502 -0.335755 -0.114135  0.0 -0.063328  1.0  0.273457
# 2     1.0  28.0 -0.149595 -0.335755 -0.175826  1.0  0.181778  1.0  0.273457
# 3     1.0  11.0 -0.075757  3.611850 -0.114135  0.0 -0.063328  1.0  0.273457
# 4     1.0  32.0 -0.084173 -0.335755 -0.051822  0.0 -0.063328  1.0  0.273457
# ...   ...   ...       ...       ...       ...  ...       ...  ...       ...
# 8279  1.0  24.0 -0.147885 -0.516489 -0.163986  0.0 -0.063328  1.0  0.147739
# 8280  1.0  14.0 -0.140195  1.424021 -0.175202  1.0  0.120348  4.0 -1.989468
# 8281  1.0  18.0 -0.150345 -0.335755 -0.176436  1.0  0.243209  3.0  0.273457
# 8282  1.0  10.0 -0.140850 -0.335755 -0.114135  0.0 -0.063328  1.0  0.273457
# 8283  1.0  14.0 -0.149320  0.282545 -0.170217  0.0 -0.063328  4.0 -1.989468
#
#            9    ...       276       277       278       279       280  \
# 0     0.615095  ... -7.874279  2.434534  2.195094 -0.752698 -0.678669
# 1     0.231411  ...  0.020449  0.017305  0.041472  0.014644  0.035096
# 2    -2.070693  ...  0.020449 -0.154844 -0.025730  1.172523  0.194832
# 3    -0.152273  ...  0.020449 -0.011387  0.041472  0.006341 -0.023094
# 4     0.615095  ...  0.020449  0.045996  0.041472  0.103460  0.093285
# ...        ...  ...       ...       ...       ...       ...       ...
# 8279 -0.152273  ...  0.003225 -0.003324  0.012105  0.003426 -0.012477
# 8280 -0.919641  ... -7.874279 -3.639924 -8.475723 -1.682572 -3.917944
# 8281  0.231411  ...  0.020449  0.017305  0.041472  0.014644  0.035096
# 8282  0.615095  ...  0.020449  0.045996  0.041472  0.103460  0.093285
# 8283  0.231411  ... -7.874279  0.915920 -1.361845 -0.106538  0.158407
#
#            281       282       283       284       285
# 0    -0.611921  0.232716  0.209828  0.189191  0.170584
# 1     0.084110  0.012392  0.029699  0.071177  0.170584
# 2     0.032374 -8.878655 -1.475316 -0.245145 -0.040734
# 3     0.084110 -0.003531  0.012860 -0.046836  0.170584
# 4     0.084110  0.232716  0.209828  0.189191  0.170584
# ...        ...       ...       ...       ...       ...
# 8279  0.045442 -0.003531  0.012860 -0.046836  0.170584
# 8280 -9.123104 -0.777777 -1.811088 -4.217199 -9.819934
# 8281  0.084110  0.012392  0.029699  0.071177  0.170584
# 8282  0.084110  0.232716  0.209828  0.189191  0.170584
# 8283 -0.235529  0.012392 -0.018426  0.027396 -0.040734
#
# [8284 rows x 286 columns]
#       0     1         2         3         4    5         6    7         8    \
# 0     1.0  11.0 -0.139587  1.709390 -0.163986  0.0 -0.063328  4.0  0.147739
# 1     1.0  12.0 -0.150254 -0.654417 -0.176324  0.0 -0.063328  1.0  0.650612
# 2     1.0  15.0 -0.150425 -0.335755 -0.175826  0.0 -0.063328  4.0  0.273457
# 3     1.0   3.0  0.014768 -0.193070 -0.051822  0.0 -0.063328  1.0  0.147739
# 4     1.0  14.0 -0.117559  2.517936 -0.051822  0.0 -0.063328  4.0  0.147739
# ...   ...   ...       ...       ...       ...  ...       ...  ...       ...
# 2067  1.0  26.0 -0.134182  1.709390 -0.114135  0.0 -0.063328  1.0  0.650612
# 2068  1.0  13.0 -0.150249  1.091090 -0.175202  0.0 -0.063328  1.0  0.273457
# 2069  1.0  11.0 -0.149292 -0.497464 -0.163986  0.0 -0.063328  1.0  0.147739
# 2070  1.0  11.0 -0.150510  1.281336 -0.176436  1.0 -0.002512  1.0 -1.989468
# 2071  1.0  21.0 -0.081903 -0.635392 -0.051822  0.0 -0.063328  4.0  0.273457
#
#            9    ...       276       277        278       279        280  \
# 0    -0.535957  ...  0.003225 -0.011698   0.012105  0.042438  -0.043914
# 1    -0.152273  ...  0.275401 -0.064457   0.234759  0.015086  -0.054945
# 2     0.615095  ...  0.020449  0.045996   0.041472  0.103460   0.093285
# 3    -0.535957  ...  0.003225 -0.011698   0.012105  0.042438  -0.043914
# 4    -0.535957  ...  0.003225 -0.011698   0.012105  0.042438  -0.043914
# ...        ...  ...       ...       ...        ...       ...        ...
# 2067  0.231411  ...  0.275401  0.097955   0.234759  0.034841   0.083500
# 2068  0.231411  ...  0.020449  0.017305   0.041472  0.014644   0.035096
# 2069  0.231411  ...  0.003225  0.005051  -0.007510  0.007912  -0.011763
# 2070  1.766147  ... -7.874279  6.990378 -12.032662 -6.205696  10.681975
# 2071  0.615095  ...  0.020449  0.045996   0.041472  0.103460   0.093285
#
#             281       282       283        284        285
# 0      0.045442 -0.153954  0.159309  -0.164850   0.170584
# 1      0.200115 -0.003531  0.012860  -0.046836   0.170584
# 2      0.084110  0.232716  0.209828   0.189191   0.170584
# 3      0.045442 -0.153954  0.159309  -0.164850   0.170584
# 4      0.045442 -0.153954  0.159309  -0.164850   0.170584
# ...         ...       ...       ...        ...        ...
# 2067   0.200115  0.012392  0.029699   0.071177   0.170584
# 2068   0.084110  0.012392  0.029699   0.071177   0.170584
# 2069   0.017491  0.012392 -0.018426   0.027396  -0.040734
# 2070 -18.387072  5.509096 -9.482904  16.323092 -28.097228
# 2071   0.084110  0.232716  0.209828   0.189191   0.170584
#
# [2072 rows x 286 columns]

# %%
for i in range(1,4):
  PF = PolynomialFeatures(degree=i)
  x_train_poly = PF.fit_transform(x_train)
  x_test_poly = PF.fit_transform(x_test)

  polynomial_reg = LinearRegression(fit_intercept=False)
  polynomial_reg.fit(x_train_poly, y_train)
  y_pred3 = polynomial_reg.predict(x_test_poly)

  print(f"Degree = {i} , mAE = {mean_absolute_error(y_test, y_pred3)}")
# Out:
# Degree = 1 , mAE = 0.6737786287577537
# Degree = 2 , mAE = 0.6718776493360523
# Degree = 3 , mAE = 1.83170589307035

# %%
y_pred3
# Out:
# array([-0.04662606,  0.05471353,  0.13045641, ..., -0.13843926,
#        -0.42715307,  0.26837686])

# %%
print("MSE : ",mean_squared_error(y_pred3,y_test))
print("MAE : ",mean_absolute_error(y_pred3,y_test))
print("R Score :",r2_score(y_pred3,y_test))
# Out:
# MSE :  1926.8105666125412
# MAE :  1.83170589307035
# R Score : -0.0013530365077272233

# %%
decision_tree_reg = DecisionTreeRegressor(max_depth=5, random_state=13)
decision_tree_reg.fit(x_train, y_train)
y_pred4 = decision_tree_reg.predict(x_test)

# %%
y_pred4
# Out:
# array([-0.03853171, -0.28783348, -0.28783348, ..., -0.28783348,
#        -0.05434075,  0.28324273])

# %%
print("MSE : ",mean_squared_error(y_pred4,y_test))
print("MAE : ",mean_absolute_error(y_pred4,y_test))
print("R Score :",r2_score(y_pred4,y_test))
# Out:
# MSE :  0.9140889274763614
# MAE :  0.6363051664556999
# R Score : -7.0258073299009745

# %%
random_forest_reg = RandomForestRegressor(n_estimators=400, max_depth=5, random_state=13)
random_forest_reg.fit(x_train, y_train)
y_pred5 = random_forest_reg.predict(x_test)

# %%
y_pred5
# Out:
# array([-0.02887002, -0.35209969, -0.25998305, ..., -0.23406684,
#        -0.13233533,  0.23357668])

# %%
print("MSE : ",mean_squared_error(y_pred5,y_test))
print("MAE : ",mean_absolute_error(y_pred5,y_test))
print("R Score :",r2_score(y_pred5,y_test))
# Out:
# MSE :  0.8958213677451973
# MAE :  0.6265775068029302
# R Score : -8.949762959927565

# %%
from sklearn.ensemble import GradientBoostingRegressor

gradboost = GradientBoostingRegressor()
gradboost.fit(x_train, y_train)

y_pred6 = gradboost.predict(x_test)

# %%
y_pred6
# Out:
# array([-0.02180015, -0.14968354, -0.32187229, ..., -0.27631692,
#        -0.31180423,  0.36811369])

# %%
print("MSE : ",mean_squared_error(y_pred6,y_test))
print("MAE : ",mean_absolute_error(y_pred6,y_test))
print("R Score :",r2_score(y_pred6,y_test))
# Out:
# MSE :  0.8578519050242616
# MAE :  0.6106355085763646
# R Score : -7.1655685832828695

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(0.001)
lasso.fit(x_train, y_train)

y_pred7 = lasso.predict(x_test)

# %%
y_pred7
# Out:
# array([ 0.07179444,  0.05248654,  0.07751281, ..., -0.04186458,
#        -0.0816269 ,  0.05494551])

# %%
print("MSE : ",mean_squared_error(y_pred7,y_test))
print("MAE : ",mean_absolute_error(y_pred7,y_test))
print("R Score :",r2_score(y_pred7,y_test))
# Out:
# MSE :  0.990619814112768
# MAE :  0.6738229982413086
# R Score : -43.44497761070198

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(x_train, y_train)

y_pred8 = ridge.predict(x_test)

# %%
print("MSE : ",mean_squared_error(y_pred8,y_test))
print("MAE : ",mean_absolute_error(y_pred8,y_test))
print("R Score :",r2_score(y_pred8,y_test))
# Out:
# MSE :  0.9900433951361195
# MAE :  0.6737806232884271
# R Score : -41.37873729638625
